# %%
# encoding: utf-8
from lxml import etree
from tqdm import tqdm_notebook as tqdm
import pandas as pd
import numpy as np
import pickle
import glob
import re

# %%
def member(xmlfile):
    tree = etree.parse(xmlfile)
    nsmap = {"xml": "http://www.w3.org/XML/1998/namespace"}
    memberlist = []
    for grantAward in tree.iterfind("grantAward"):
        awardnumber = grantAward.get("awardNumber")
        for member in grantAward.find("summary[@xml:lang='ja']", nsmap).iterfind("member", nsmap):
            sequence = member.get("sequence")
            role = member.get("role")
            kenkyuusha_id = member.get("eradCode")

            try:
                familyname = member.find("personalName/familyName").text
            except:
                familyname = np.NaN

            try:
                givenname = member.find("personalName/givenName").text
            except:
                givenname = np.NaN

            row = [
                awardnumber,
                sequence,
                role,
                kenkyuusha_id,
                familyname,
                givenname,
            ]
            memberlist.append(row)

    df = pd.DataFrame(memberlist)
    df.columns = [
        'awardnumber',
        'sequence',
        'role',
        'kenkyuusha_id',
        'familyname',
        'givenname',
    ]

    pickledfile = 'pickledDF_member_from_summary/' + re.search('[0-9]{4}_[0-9]+-[0-9]+.xml', xmlfile).group() + '.dump'
    df.to_pickle(pickledfile)

# %%
import os
import shutil

def cleandir(dirname):
    if os.path.isdir(dirname):
        shutil.rmtree(dirname)
    os.mkdir(dirname)

cleandir('pickledDF_member_from_summary')

# %%
for xmlfile in tqdm(glob.glob('xml/201*.xml')):
    member(xmlfile)
# Out:
# HBox(children=(IntProgress(value=0, max=295), HTML(value='')))
# C:\Users\OWNER\Anaconda3\lib\site-packages\tqdm\_monitor.py:89: TqdmSynchronisationWarning: Set changed size during iteration (see https://github.com/tqdm/tqdm/issues/481)
#   TqdmSynchronisationWarning)

# %%
columns = [
    'awardnumber',
    'sequence',
    'role',
    'kenkyuusha_id',
    'familyname',
    'givenname',
]
df = pd.DataFrame(columns=columns)

# %%
for dump in tqdm(glob.glob('pickledDF_member_from_summary/*.dump')):
    with open(dump, mode='rb') as f:
        df = pd.concat([df, pickle.load(f)])
# Out:
# HBox(children=(IntProgress(value=0, max=295), HTML(value='')))

# %%
df.to_pickle('beforeCleaning/parse_member_from_summary.dump')

# %%
with open('beforeCleaning/parse_member_from_summary.dump', mode='rb') as f:
    df = pickle.load(f)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 262523 entries, 0 to 499
# Data columns (total 6 columns):
# awardnumber      262523 non-null object
# sequence         262523 non-null object
# role             262523 non-null object
# kenkyuusha_id    235080 non-null object
# familyname       261707 non-null object
# givenname        261756 non-null object
# dtypes: object(6)
# memory usage: 14.0+ MB

# %%
df = df.fillna(0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 262523 entries, 0 to 499
# Data columns (total 6 columns):
# awardnumber      262523 non-null object
# sequence         262523 non-null object
# role             262523 non-null object
# kenkyuusha_id    262523 non-null object
# familyname       262523 non-null object
# givenname        262523 non-null object
# dtypes: object(6)
# memory usage: 14.0+ MB

# %%
df = df.reset_index(drop=True)
df
# Out:
#        awardnumber sequence                    role kenkyuusha_id familyname  \
# 0             4603        1          area_organizer      50233127         太田
# 1             4602        1          area_organizer      80186618         神田
# 2             4601        1          area_organizer      60262101         植田
# 3             3608        1          area_organizer      20148315        祖父江
# 4             3607        1          area_organizer      40272710         田口
# 5             3606        1          area_organizer      70244126         岩間
# 6             3605        1          area_organizer      50580974         藤田
# 7             3604        1          area_organizer      30273220         廣瀬
# 8             3603        1          area_organizer      90211903         小林
# 9             3602        1          area_organizer      80212265          森
# 10            3601        1          area_organizer      00294059         田中
# 11        26935006        1  principal_investigator             0         鈴木
# 12        26935005        1  principal_investigator             0         石川
# 13        26935004        1  principal_investigator             0         孕石
# 14        26935003        1  principal_investigator             0         楢府
# 15        26935002        1  principal_investigator             0         櫻井
# 16        26935001        1  principal_investigator             0         太田
# 17        26934018        1  principal_investigator             0         若松
# 18        26934017        1  principal_investigator             0         北島
# 19        26934016        1  principal_investigator             0         山口
# 20        26934015        1  principal_investigator             0         早坂
# 21        26934014        1  principal_investigator             0         曽田
# 22        26934013        1  principal_investigator             0         澤木
# 23        26934012        1  principal_investigator             0         関口
# 24        26934011        1  principal_investigator             0         近藤
# 25        26934010        1  principal_investigator             0         吉井
# 26        26934009        1  principal_investigator             0         藤本
# 27        26934008        1  principal_investigator             0         福田
# 28        26934007        1  principal_investigator             0         平井
# 29        26934006        1  principal_investigator             0         野村
# ...            ...      ...                     ...           ...        ...
# 262493    18K08461        1  principal_investigator      30510391         永井
# 262494    18K08460        1  principal_investigator      60361218         鍬田
# 262495    18K08459        1  principal_investigator      60401121         瀬尾
# 262496    18K08458        1  principal_investigator      30508643         原田
# 262497    18K08457        1  principal_investigator      20399463         吉河
# 262498    18K08456        1  principal_investigator      30407093         吉澤
# 262499    18K08455        1  principal_investigator      00455338         川野
# 262500    18K08454        1  principal_investigator      90283522        伊奈田
# 262501    18K08453        1  principal_investigator      70294725         奥村
# 262502    18K08452        1  principal_investigator      90246695         石井
# 262503    18K08451        1  principal_investigator      80424711         小松
# 262504    18K08450        1  principal_investigator      80328377         越野
# 262505    18K08449        1  principal_investigator      80459312         上田
# 262506    18K08448        1  principal_investigator      60365591         片山
# 262507    18K08447        1  principal_investigator      00292855         高橋
# 262508    18K08446        1  principal_investigator      00746993         樽本
# 262509    18K08445        1  principal_investigator      20372881         吉野
# 262510    18K08444        1  principal_investigator      10405277         新屋
# 262511    18K08443        1  principal_investigator      40336673         井坂
# 262512    18K08442        1  principal_investigator      90277971         金光
# 262513    18K08441        1  principal_investigator      50305356         石岡
# 262514    18K08440        1  principal_investigator      30736690         仲村
# 262515    18K08439        1  principal_investigator      80301381         平松
# 262516    18K08438        1  principal_investigator      60303913         有海
# 262517    18K08437        1  principal_investigator      90573105   MIYAZATO
# 262518    18K08436        1  principal_investigator      40628492         中田
# 262519    18K08435        1  principal_investigator      30575080         天野
# 262520    18K08434        1  principal_investigator      00346925         井上
# 262521    18K08433        1  principal_investigator      10346786         古庄
# 262522    18K08432        1  principal_investigator      20325476         白土
#
#        givenname
# 0              順
# 1             大輔
# 2             一博
# 3              元
# 4             英樹
# 5             厚志
# 6             恭之
# 7             哲郎
# 8             和人
# 9             泰生
# 10            正人
# 11            秀茂
# 12            芳恵
# 13            泰孝
# 14            暢子
# 15            雅子
# 16             聡
# 17            純子
# 18           百合子
# 19           志津子
# 20           真貴子
# 21            武史
# 22            弘二
# 23            道彦
# 24            崇史
# 25            健人
# 26            隆弘
# 27            忠且
# 28            源樹
# 29           いずみ
# ...          ...
# 262493        英明
# 262494        伸好
# 262495        幸子
# 262496        恵嘉
# 262497        智城
# 262498        彰宏
# 262499        光興
# 262500        宏康
# 262501        裕司
# 262502        良和
# 262503        陽樹
# 262504        一朗
# 262505       たかね
# 262506        由紀
# 262507         孝
# 262508        憲人
# 262509        直人
# 262510        政春
# 262511        雅徳
# 262512        敬二
# 262513         賢
# 262514         究
# 262515        和史
# 262516        康雄
# 262517     PAOLA
# 262518        浩智
# 262519        将之
# 262520        真吾
# 262521        憲浩
# 262522        基明
#
# [262523 rows x 6 columns]

# %%
df['kenkyuusha_id'].str.match('^[0-9]*$').value_counts()
# Out:
# True    235080
# Name: kenkyuusha_id, dtype: int64

# %%
falselist = df['kenkyuusha_id'].str.match('^[0-9]*$')
falselist = list(falselist[falselist == False].index)
df.loc[falselist]
# Out:
# Empty DataFrame
# Columns: [awardnumber, sequence, role, kenkyuusha_id, familyname, givenname]
# Index: []

# %%
#df.kenkyuusha_id.replace('235000 6', 50004619, inplace=True)
#df.kenkyuusha_id.replace('2033+220', 80224103, inplace=True)
#df.kenkyuusha_id.replace('A9406506', 10226110, inplace=True)
df.kenkyuusha_id.replace('08J05773', 50571535, inplace=True)
df.kenkyuusha_id.replace('12J00079', 40737251, inplace=True)

# %%
df.loc[falselist]
# Out:
# Empty DataFrame
# Columns: [awardnumber, sequence, role, kenkyuusha_id, familyname, givenname]
# Index: []

# %%
df = df.astype({
    'sequence': np.int64,
    'kenkyuusha_id': np.int64,
})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 262523 entries, 0 to 262522
# Data columns (total 6 columns):
# awardnumber      262523 non-null object
# sequence         262523 non-null int64
# role             262523 non-null object
# kenkyuusha_id    262523 non-null int64
# familyname       262523 non-null object
# givenname        262523 non-null object
# dtypes: int64(2), object(4)
# memory usage: 12.0+ MB

# %%
df.duplicated().any()
# Out:
# False

# %%
df.role.value_counts()
# Out:
# principal_investigator            132984
# co_investigator_buntan             96340
# research_collaborator              12476
# research_fellow                    11777
# co_investigator_renkei              5952
# foreign_research_fellow             1380
# host_researcher                     1379
# co_investigator_buntan_support       147
# area_organizer                        81
# principal_investigator_support         7
# Name: role, dtype: int64

# %%
df = df[(df['role'] == 'principal_investigator') | (df['role'] == 'area_organizer') | (df['role'] == 'principal_investigator_support')]
df
# Out:
#        awardnumber  sequence                    role  kenkyuusha_id  \
# 0             4603         1          area_organizer       50233127
# 1             4602         1          area_organizer       80186618
# 2             4601         1          area_organizer       60262101
# 3             3608         1          area_organizer       20148315
# 4             3607         1          area_organizer       40272710
# 5             3606         1          area_organizer       70244126
# 6             3605         1          area_organizer       50580974
# 7             3604         1          area_organizer       30273220
# 8             3603         1          area_organizer       90211903
# 9             3602         1          area_organizer       80212265
# 10            3601         1          area_organizer         294059
# 11        26935006         1  principal_investigator              0
# 12        26935005         1  principal_investigator              0
# 13        26935004         1  principal_investigator              0
# 14        26935003         1  principal_investigator              0
# 15        26935002         1  principal_investigator              0
# 16        26935001         1  principal_investigator              0
# 17        26934018         1  principal_investigator              0
# 18        26934017         1  principal_investigator              0
# 19        26934016         1  principal_investigator              0
# 20        26934015         1  principal_investigator              0
# 21        26934014         1  principal_investigator              0
# 22        26934013         1  principal_investigator              0
# 23        26934012         1  principal_investigator              0
# 24        26934011         1  principal_investigator              0
# 25        26934010         1  principal_investigator              0
# 26        26934009         1  principal_investigator              0
# 27        26934008         1  principal_investigator              0
# 28        26934007         1  principal_investigator              0
# 29        26934006         1  principal_investigator              0
# ...            ...       ...                     ...            ...
# 262493    18K08461         1  principal_investigator       30510391
# 262494    18K08460         1  principal_investigator       60361218
# 262495    18K08459         1  principal_investigator       60401121
# 262496    18K08458         1  principal_investigator       30508643
# 262497    18K08457         1  principal_investigator       20399463
# 262498    18K08456         1  principal_investigator       30407093
# 262499    18K08455         1  principal_investigator         455338
# 262500    18K08454         1  principal_investigator       90283522
# 262501    18K08453         1  principal_investigator       70294725
# 262502    18K08452         1  principal_investigator       90246695
# 262503    18K08451         1  principal_investigator       80424711
# 262504    18K08450         1  principal_investigator       80328377
# 262505    18K08449         1  principal_investigator       80459312
# 262506    18K08448         1  principal_investigator       60365591
# 262507    18K08447         1  principal_investigator         292855
# 262508    18K08446         1  principal_investigator         746993
# 262509    18K08445         1  principal_investigator       20372881
# 262510    18K08444         1  principal_investigator       10405277
# 262511    18K08443         1  principal_investigator       40336673
# 262512    18K08442         1  principal_investigator       90277971
# 262513    18K08441         1  principal_investigator       50305356
# 262514    18K08440         1  principal_investigator       30736690
# 262515    18K08439         1  principal_investigator       80301381
# 262516    18K08438         1  principal_investigator       60303913
# 262517    18K08437         1  principal_investigator       90573105
# 262518    18K08436         1  principal_investigator       40628492
# 262519    18K08435         1  principal_investigator       30575080
# 262520    18K08434         1  principal_investigator         346925
# 262521    18K08433         1  principal_investigator       10346786
# 262522    18K08432         1  principal_investigator       20325476
#
#        familyname givenname
# 0              太田         順
# 1              神田        大輔
# 2              植田        一博
# 3             祖父江         元
# 4              田口        英樹
# 5              岩間        厚志
# 6              藤田        恭之
# 7              廣瀬        哲郎
# 8              小林        和人
# 9               森        泰生
# 10             田中        正人
# 11             鈴木        秀茂
# 12             石川        芳恵
# 13             孕石        泰孝
# 14             楢府        暢子
# 15             櫻井        雅子
# 16             太田         聡
# 17             若松        純子
# 18             北島       百合子
# 19             山口       志津子
# 20             早坂       真貴子
# 21             曽田        武史
# 22             澤木        弘二
# 23             関口        道彦
# 24             近藤        崇史
# 25             吉井        健人
# 26             藤本        隆弘
# 27             福田        忠且
# 28             平井        源樹
# 29             野村       いずみ
# ...           ...       ...
# 262493         永井        英明
# 262494         鍬田        伸好
# 262495         瀬尾        幸子
# 262496         原田        恵嘉
# 262497         吉河        智城
# 262498         吉澤        彰宏
# 262499         川野        光興
# 262500        伊奈田        宏康
# 262501         奥村        裕司
# 262502         石井        良和
# 262503         小松        陽樹
# 262504         越野        一朗
# 262505         上田       たかね
# 262506         片山        由紀
# 262507         高橋         孝
# 262508         樽本        憲人
# 262509         吉野        直人
# 262510         新屋        政春
# 262511         井坂        雅徳
# 262512         金光        敬二
# 262513         石岡         賢
# 262514         仲村         究
# 262515         平松        和史
# 262516         有海        康雄
# 262517   MIYAZATO     PAOLA
# 262518         中田        浩智
# 262519         天野        将之
# 262520         井上        真吾
# 262521         古庄        憲浩
# 262522         白土        基明
#
# [133072 rows x 6 columns]

# %%
seqmax = df.groupby('awardnumber')['sequence'].max().reset_index()
seqmax
# Out:
#        awardnumber  sequence
# 0         15H00001         1
# 1         15H00002         1
# 2         15H00003         1
# 3         15H00004         1
# 4         15H00005         1
# 5         15H00006         1
# 6         15H00007         1
# 7         15H00008         1
# 8         15H00009         1
# 9         15H00010         1
# 10        15H00011         1
# 11        15H00012         1
# 12        15H00013         1
# 13        15H00014         1
# 14        15H00015         1
# 15        15H00016         1
# 16        15H00017         1
# 17        15H00018         1
# 18        15H00019         1
# 19        15H00020         1
# 20        15H00021         1
# 21        15H00022         1
# 22        15H00023         1
# 23        15H00024         1
# 24        15H00025         1
# 25        15H00026         1
# 26        15H00027         1
# 27        15H00028         1
# 28        15H00029         1
# 29        15H00030         1
# ...            ...       ...
# 133042        3802         1
# 133043        3803         1
# 133044        3804         1
# 133045        3805         1
# 133046        3806         1
# 133047        3901         1
# 133048        3902         1
# 133049        3903         1
# 133050        3904         1
# 133051        3905         1
# 133052        4601         1
# 133053        4602         1
# 133054        4603         1
# 133055        4701         1
# 133056        4702         1
# 133057        4703         1
# 133058        4704         1
# 133059        4705         1
# 133060        4801         1
# 133061        4802         1
# 133062        4803         1
# 133063        4804         1
# 133064        4805         1
# 133065        4806         1
# 133066        4901         1
# 133067        4902         1
# 133068        4903         1
# 133069        4904         1
# 133070        4905         1
# 133071        4906         1
#
# [133072 rows x 2 columns]

# %%
seqmax['awardnumber'].nunique(dropna=False)
# Out:
# 133072

# %%
df = pd.merge(seqmax, df, on=['awardnumber', 'sequence'])
df
# Out:
#        awardnumber  sequence                    role  kenkyuusha_id  \
# 0         15H00001         1  principal_investigator              0
# 1         15H00002         1  principal_investigator              0
# 2         15H00003         1  principal_investigator              0
# 3         15H00004         1  principal_investigator              0
# 4         15H00005         1  principal_investigator              0
# 5         15H00006         1  principal_investigator              0
# 6         15H00007         1  principal_investigator              0
# 7         15H00008         1  principal_investigator              0
# 8         15H00009         1  principal_investigator              0
# 9         15H00010         1  principal_investigator              0
# 10        15H00011         1  principal_investigator              0
# 11        15H00012         1  principal_investigator              0
# 12        15H00013         1  principal_investigator              0
# 13        15H00014         1  principal_investigator              0
# 14        15H00015         1  principal_investigator              0
# 15        15H00016         1  principal_investigator              0
# 16        15H00017         1  principal_investigator              0
# 17        15H00018         1  principal_investigator              0
# 18        15H00019         1  principal_investigator              0
# 19        15H00020         1  principal_investigator              0
# 20        15H00021         1  principal_investigator              0
# 21        15H00022         1  principal_investigator              0
# 22        15H00023         1  principal_investigator              0
# 23        15H00024         1  principal_investigator              0
# 24        15H00025         1  principal_investigator              0
# 25        15H00026         1  principal_investigator              0
# 26        15H00027         1  principal_investigator              0
# 27        15H00028         1  principal_investigator              0
# 28        15H00029         1  principal_investigator              0
# 29        15H00030         1  principal_investigator              0
# ...            ...       ...                     ...            ...
# 133042        3802         1          area_organizer       80300953
# 133043        3803         1          area_organizer       80224369
# 133044        3804         1          area_organizer       60221595
# 133045        3805         1          area_organizer       70135838
# 133046        3806         1          area_organizer         313205
# 133047        3901         1          area_organizer       50273850
# 133048        3902         1          area_organizer         178089
# 133049        3903         1          area_organizer       80221810
# 133050        3904         1          area_organizer       70271020
# 133051        3905         1          area_organizer       80303915
# 133052        4601         1          area_organizer       60262101
# 133053        4602         1          area_organizer       80186618
# 133054        4603         1          area_organizer       50233127
# 133055        4701         1          area_organizer       50128104
# 133056        4702         1          area_organizer       80270792
# 133057        4703         1          area_organizer       80180553
# 133058        4704         1          area_organizer       20726260
# 133059        4705         1          area_organizer       20396162
# 133060        4801         1          area_organizer       80322056
# 133061        4802         1          area_organizer         220343
# 133062        4803         1          area_organizer       80228410
# 133063        4804         1          area_organizer       30322332
# 133064        4805         1          area_organizer       80188846
# 133065        4806         1          area_organizer       60251055
# 133066        4901         1          area_organizer       50222427
# 133067        4902         1          area_organizer       90431478
# 133068        4903         1          area_organizer       30211121
# 133069        4904         1          area_organizer       20280951
# 133070        4905         1          area_organizer         291964
# 133071        4906         1          area_organizer       60261161
#
#        familyname givenname
# 0              江谷        和樹
# 1              北田        聖子
# 2              多田        英俊
# 3              國本        学史
# 4              北川        美穂
# 5              原口       耕一郎
# 6              森上        優子
# 7              髙木        浩明
# 8               林        圭介
# 9              山本        和雄
# 10             井上         幸
# 11             漆﨑        まり
# 12              張        栄順
# 13             今田        水穂
# 14             長村        祥知
# 15              辻        伸幸
# 16             東野        裕子
# 17              栁        素子
# 18             江口        朗子
# 19             金澤        淳子
# 20             中村        菜穂
# 21             松村        悠子
# 22             柿沼        亮介
# 23             北脇        義友
# 24             栗林        幸雄
# 25             豊田        裕章
# 26             新田        康二
# 27             水村        暁人
# 28             猪熊        樹人
# 29             尾島        志保
# ...           ...       ...
# 133042         榎本        和生
# 133043         影山       龍一郎
# 133044         松本         満
# 133045         河岡        義裕
# 133046         東山        哲也
# 133047         黒田        真也
# 133048         倉谷         滋
# 133049         梅田        正明
# 133050         清水        重臣
# 133051         立花         誠
# 133052         植田        一博
# 133053         神田        大輔
# 133054         太田         順
# 133055         宮野         悟
# 133056         安田        一郎
# 133057         南部         篤
# 133058         古川         聡
# 133059         西田        眞也
# 133060         笠井        清登
# 133061         大隅        典子
# 133062         橋本        浩一
# 133063         武川        睦寛
# 133064         銅谷        賢治
# 133065         桜井         武
# 133066         松島        綱治
# 133067         川村        賢二
# 133068        岡ノ谷        一夫
# 133069         藤田        直也
# 133070         尾藤        晴彦
# 133071          沈        建仁
#
# [133072 rows x 6 columns]

# %%
seqmax['awardnumber'].nunique(dropna=False)
# Out:
# 133072

# %%
df = df.set_index('awardnumber')
df
# Out:
#              sequence                    role  kenkyuusha_id familyname  \
# awardnumber
# 15H00001            1  principal_investigator              0         江谷
# 15H00002            1  principal_investigator              0         北田
# 15H00003            1  principal_investigator              0         多田
# 15H00004            1  principal_investigator              0         國本
# 15H00005            1  principal_investigator              0         北川
# 15H00006            1  principal_investigator              0         原口
# 15H00007            1  principal_investigator              0         森上
# 15H00008            1  principal_investigator              0         髙木
# 15H00009            1  principal_investigator              0          林
# 15H00010            1  principal_investigator              0         山本
# 15H00011            1  principal_investigator              0         井上
# 15H00012            1  principal_investigator              0         漆﨑
# 15H00013            1  principal_investigator              0          張
# 15H00014            1  principal_investigator              0         今田
# 15H00015            1  principal_investigator              0         長村
# 15H00016            1  principal_investigator              0          辻
# 15H00017            1  principal_investigator              0         東野
# 15H00018            1  principal_investigator              0          栁
# 15H00019            1  principal_investigator              0         江口
# 15H00020            1  principal_investigator              0         金澤
# 15H00021            1  principal_investigator              0         中村
# 15H00022            1  principal_investigator              0         松村
# 15H00023            1  principal_investigator              0         柿沼
# 15H00024            1  principal_investigator              0         北脇
# 15H00025            1  principal_investigator              0         栗林
# 15H00026            1  principal_investigator              0         豊田
# 15H00027            1  principal_investigator              0         新田
# 15H00028            1  principal_investigator              0         水村
# 15H00029            1  principal_investigator              0         猪熊
# 15H00030            1  principal_investigator              0         尾島
# ...               ...                     ...            ...        ...
# 3802                1          area_organizer       80300953         榎本
# 3803                1          area_organizer       80224369         影山
# 3804                1          area_organizer       60221595         松本
# 3805                1          area_organizer       70135838         河岡
# 3806                1          area_organizer         313205         東山
# 3901                1          area_organizer       50273850         黒田
# 3902                1          area_organizer         178089         倉谷
# 3903                1          area_organizer       80221810         梅田
# 3904                1          area_organizer       70271020         清水
# 3905                1          area_organizer       80303915         立花
# 4601                1          area_organizer       60262101         植田
# 4602                1          area_organizer       80186618         神田
# 4603                1          area_organizer       50233127         太田
# 4701                1          area_organizer       50128104         宮野
# 4702                1          area_organizer       80270792         安田
# 4703                1          area_organizer       80180553         南部
# 4704                1          area_organizer       20726260         古川
# 4705                1          area_organizer       20396162         西田
# 4801                1          area_organizer       80322056         笠井
# 4802                1          area_organizer         220343         大隅
# 4803                1          area_organizer       80228410         橋本
# 4804                1          area_organizer       30322332         武川
# 4805                1          area_organizer       80188846         銅谷
# 4806                1          area_organizer       60251055         桜井
# 4901                1          area_organizer       50222427         松島
# 4902                1          area_organizer       90431478         川村
# 4903                1          area_organizer       30211121        岡ノ谷
# 4904                1          area_organizer       20280951         藤田
# 4905                1          area_organizer         291964         尾藤
# 4906                1          area_organizer       60261161          沈
#
#             givenname
# awardnumber
# 15H00001           和樹
# 15H00002           聖子
# 15H00003           英俊
# 15H00004           学史
# 15H00005           美穂
# 15H00006          耕一郎
# 15H00007           優子
# 15H00008           浩明
# 15H00009           圭介
# 15H00010           和雄
# 15H00011            幸
# 15H00012           まり
# 15H00013           栄順
# 15H00014           水穂
# 15H00015           祥知
# 15H00016           伸幸
# 15H00017           裕子
# 15H00018           素子
# 15H00019           朗子
# 15H00020           淳子
# 15H00021           菜穂
# 15H00022           悠子
# 15H00023           亮介
# 15H00024           義友
# 15H00025           幸雄
# 15H00026           裕章
# 15H00027           康二
# 15H00028           暁人
# 15H00029           樹人
# 15H00030           志保
# ...               ...
# 3802               和生
# 3803              龍一郎
# 3804                満
# 3805               義裕
# 3806               哲也
# 3901               真也
# 3902                滋
# 3903               正明
# 3904               重臣
# 3905                誠
# 4601               一博
# 4602               大輔
# 4603                順
# 4701                悟
# 4702               一郎
# 4703                篤
# 4704                聡
# 4705               眞也
# 4801               清登
# 4802               典子
# 4803               浩一
# 4804               睦寛
# 4805               賢治
# 4806                武
# 4901               綱治
# 4902               賢二
# 4903               一夫
# 4904               直也
# 4905               晴彦
# 4906               建仁
#
# [133072 rows x 5 columns]

# %%
df.to_pickle('afterCleaning/parse_member_from_summary.dump')
