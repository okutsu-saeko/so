# %%
# encoding: utf-8
from lxml import etree
from tqdm import tqdm_notebook as tqdm
import pandas as pd
import numpy as np
import pickle
import glob
import re

# %%
def kadai(xmlfile):
    tree = etree.parse(xmlfile)
    nsmap = {"xml": "http://www.w3.org/XML/1998/namespace"}
    kadailist = []
    for grantAward in tree.iterfind("grantAward"):
        projecttype = grantAward.get("projectType")
        awardnumber = grantAward.get("awardNumber")
        startfiscalyear = grantAward.find("summary[@xml:lang='ja']/periodOfAward", nsmap).get("searchStartFiscalYear")
        endfiscalyear = grantAward.find("summary[@xml:lang='ja']/periodOfAward", nsmap).get("searchEndFiscalYear")

        try:
            category_niicode = grantAward.find("summary[@xml:lang='ja']/category", nsmap).get("niiCode")
        except:
            category_niicode = np.NaN
        
        try:
            category = grantAward.find("summary[@xml:lang='ja']/category", nsmap).text
        except:
            category = np.NaN
            
        try:
            section_niicode = grantAward.find("summary[@xml:lang='ja']/section", nsmap).get("niiCode")
        except:
            section_niicode = np.NaN
        
        try:
            section = grantAward.find("summary[@xml:lang='ja']/section", nsmap).text
        except:
            section = np.NaN

        try:
            title_ja = grantAward.find("summary[@xml:lang='ja']/title", nsmap).text
        except:
            title_ja = np.NaN
        
        try:
            title_en = grantAward.find("summary[@xml:lang='en']/title", nsmap).text
        except:
            title_en = np.NaN
        
        try:
            directcost = grantAward.find("summary[@xml:lang='ja']/overallAwardAmount/directCost", nsmap).text
        except:
            directcost = np.NaN

        row = [
            awardnumber,
            projecttype,
            category,
            category_niicode,
            section,
            section_niicode,
            startfiscalyear,
            endfiscalyear,
            directcost,
            title_ja,
            title_en,
        ]
        kadailist.append(row)
        
    df = pd.DataFrame(kadailist)
    df.columns = [
        'awardnumber',
        'projecttype',
        'category',
        'category_niicode',
        'section',
        'section_niicode',
        'startfiscalyear',
        'endfiscalyear',
        'directcost',
        'title_ja',
        'title_en',
    ]
    
    pickledfile = 'pickledDF_grantaward_main/' + re.search('[0-9]{4}_[0-9]+-[0-9]+.xml', xmlfile).group() + '.dump'
    df.to_pickle(pickledfile)

# %%
import os
import shutil

def cleandir(dirname):
    if os.path.isdir(dirname):
        shutil.rmtree(dirname)
    os.mkdir(dirname)

cleandir('pickledDF_grantaward_main')

# %%
for xmlfile in tqdm(glob.glob('xml/201*.xml')):
    kadai(xmlfile)
# Out:
# HBox(children=(IntProgress(value=0, max=295), HTML(value='')))
# C:\Users\OWNER\Anaconda3\lib\site-packages\tqdm\_monitor.py:89: TqdmSynchronisationWarning: Set changed size during iteration (see https://github.com/tqdm/tqdm/issues/481)
#   TqdmSynchronisationWarning)

# %%
columns = [
    'awardnumber',
    'projecttype',
    'category',
    'category_niicode',
    'section',
    'section_niicode',
    'startfiscalyear',
    'endfiscalyear',
    'directcost',
    'title_ja',
    'title_en',
]
df = pd.DataFrame(columns=columns)

# %%
for dump in tqdm(glob.glob('pickledDF_grantaward_main/201*.dump')):
    with open(dump, mode='rb') as f:
        df = pd.concat([df, pickle.load(f)])
# Out:
# HBox(children=(IntProgress(value=0, max=295), HTML(value='')))
# C:\Users\OWNER\Anaconda3\lib\site-packages\tqdm\_monitor.py:89: TqdmSynchronisationWarning: Set changed size during iteration (see https://github.com/tqdm/tqdm/issues/481)
#   TqdmSynchronisationWarning)

# %%
df.to_pickle('beforeCleaning/parse_grantaward_main.dump')

# %%
with open('beforeCleaning/parse_grantaward_main.dump', mode='rb') as f:
    df = pickle.load(f)

# %%
df
# Out:
#     awardnumber projecttype          category category_niicode section  \
# 0          4603        area  新学術領域研究(研究領域提案型)               73     NaN
# 1          4602        area  新学術領域研究(研究領域提案型)               73     NaN
# 2          4601        area  新学術領域研究(研究領域提案型)               73     NaN
# 3          3608        area  新学術領域研究(研究領域提案型)               73     NaN
# 4          3607        area  新学術領域研究(研究領域提案型)               73     NaN
# 5          3606        area  新学術領域研究(研究領域提案型)               73     NaN
# 6          3605        area  新学術領域研究(研究領域提案型)               73     NaN
# 7          3604        area  新学術領域研究(研究領域提案型)               73     NaN
# 8          3603        area  新学術領域研究(研究領域提案型)               73     NaN
# 9          3602        area  新学術領域研究(研究領域提案型)               73     NaN
# 10         3601        area  新学術領域研究(研究領域提案型)               73     NaN
# 11     26935006     project              奨励研究               63     NaN
# 12     26935005     project              奨励研究               63     NaN
# 13     26935004     project              奨励研究               63     NaN
# 14     26935003     project              奨励研究               63     NaN
# 15     26935002     project              奨励研究               63     NaN
# 16     26935001     project              奨励研究               63     NaN
# 17     26934018     project              奨励研究               63     NaN
# 18     26934017     project              奨励研究               63     NaN
# 19     26934016     project              奨励研究               63     NaN
# 20     26934015     project              奨励研究               63     NaN
# 21     26934014     project              奨励研究               63     NaN
# 22     26934013     project              奨励研究               63     NaN
# 23     26934012     project              奨励研究               63     NaN
# 24     26934011     project              奨励研究               63     NaN
# 25     26934010     project              奨励研究               63     NaN
# 26     26934009     project              奨励研究               63     NaN
# 27     26934008     project              奨励研究               63     NaN
# 28     26934007     project              奨励研究               63     NaN
# 29     26934006     project              奨励研究               63     NaN
# ..          ...         ...               ...              ...     ...
# 470    18K08461     project           基盤研究(C)               72      一般
# 471    18K08460     project           基盤研究(C)               72      一般
# 472    18K08459     project           基盤研究(C)               72      一般
# 473    18K08458     project           基盤研究(C)               72      一般
# 474    18K08457     project           基盤研究(C)               72      一般
# 475    18K08456     project           基盤研究(C)               72      一般
# 476    18K08455     project           基盤研究(C)               72      一般
# 477    18K08454     project           基盤研究(C)               72      一般
# 478    18K08453     project           基盤研究(C)               72      一般
# 479    18K08452     project           基盤研究(C)               72      一般
# 480    18K08451     project           基盤研究(C)               72      一般
# 481    18K08450     project           基盤研究(C)               72      一般
# 482    18K08449     project           基盤研究(C)               72      一般
# 483    18K08448     project           基盤研究(C)               72      一般
# 484    18K08447     project           基盤研究(C)               72      一般
# 485    18K08446     project           基盤研究(C)               72      一般
# 486    18K08445     project           基盤研究(C)               72      一般
# 487    18K08444     project           基盤研究(C)               72      一般
# 488    18K08443     project           基盤研究(C)               72      一般
# 489    18K08442     project           基盤研究(C)               72      一般
# 490    18K08441     project           基盤研究(C)               72      一般
# 491    18K08440     project           基盤研究(C)               72      一般
# 492    18K08439     project           基盤研究(C)               72      一般
# 493    18K08438     project           基盤研究(C)               72      一般
# 494    18K08437     project           基盤研究(C)               72      一般
# 495    18K08436     project           基盤研究(C)               72      一般
# 496    18K08435     project           基盤研究(C)               72      一般
# 497    18K08434     project           基盤研究(C)               72      一般
# 498    18K08433     project           基盤研究(C)               72      一般
# 499    18K08432     project           基盤研究(C)               72      一般
#
#     section_niicode startfiscalyear endfiscalyear directcost  \
# 0               NaN            2014          2018        NaN
# 1               NaN            2014          2018        NaN
# 2               NaN            2014          2018        NaN
# 3               NaN            2014          2018        NaN
# 4               NaN            2014          2018        NaN
# 5               NaN            2014          2018        NaN
# 6               NaN            2014          2018        NaN
# 7               NaN            2014          2018        NaN
# 8               NaN            2014          2018        NaN
# 9               NaN            2014          2018        NaN
# 10              NaN            2014          2018        NaN
# 11              NaN            2014          2014     600000
# 12              NaN            2014          2014     400000
# 13              NaN            2014          2014     400000
# 14              NaN            2014          2014     600000
# 15              NaN            2014          2014     400000
# 16              NaN            2014          2014     600000
# 17              NaN            2014          2014     600000
# 18              NaN            2014          2014     600000
# 19              NaN            2014          2014     400000
# 20              NaN            2014          2014     300000
# 21              NaN            2014          2015     600000
# 22              NaN            2014          2014     500000
# 23              NaN            2014          2014     600000
# 24              NaN            2014          2014     400000
# 25              NaN            2014          2014     500000
# 26              NaN            2014          2014     500000
# 27              NaN            2014          2014     300000
# 28              NaN            2014          2014     400000
# 29              NaN            2014          2014     300000
# ..              ...             ...           ...        ...
# 470              17            2018          2020    3400000
# 471              17            2018          2020    3400000
# 472              17            2018          2020    3300000
# 473              17            2018          2020    3500000
# 474              17            2018          2020    3400000
# 475              17            2018          2020    3400000
# 476              17            2018          2020    3400000
# 477              17            2018          2020    3400000
# 478              17            2018          2020    3400000
# 479              17            2018          2020    3400000
# 480              17            2018          2020    3500000
# 481              17            2018          2020    3300000
# 482              17            2018          2020    3400000
# 483              17            2018          2020    3400000
# 484              17            2018          2020    3400000
# 485              17            2018          2020    3400000
# 486              17            2018          2020    3200000
# 487              17            2018          2020    3400000
# 488              17            2018          2021    3400000
# 489              17            2018          2022    3300000
# 490              17            2018          2020    3200000
# 491              17            2018          2020    1500000
# 492              17            2018          2020    3200000
# 493              17            2018          2020    3400000
# 494              17            2018          2020    3400000
# 495              17            2018          2020    3300000
# 496              17            2018          2020    3400000
# 497              17            2018          2020    3500000
# 498              17            2018          2020    3400000
# 499              17            2018          2020    3400000
#
#                                      title_ja  \
# 0                           脳内身体表現の変容機構の理解と制御
# 1        動的構造生命科学を拓く新発想測定技術－タンパク質が動作する姿を活写する－
# 2     認知的インタラクションデザイン学：意思疎通のモデル論的理解と人工物設計への応用
# 3                              脳タンパク質老化と認知症制御
# 4                                     新生鎖の生物学
# 5                        ステムセルエイジングから解明する疾患原理
# 6                       細胞競合：細胞社会を支える適者生存システム
# 7                          ノンコーディングＲＮＡネオタクソノミ
# 8                        行動適応を担う脳神経回路の機能シフト機構
# 9                         酸素を基軸とする生命の新たな統合的理解
# 10                     細胞死を起点とする生体制御ネットワークの解明
# 11     超高精細４Ｋ映像による可視化金型粉砕機を用いたアルファ穀物粉の粉砕挙動の解明
# 12         小学校における持続可能な社会をめざすための消費者教育の実践事例集作成
# 13                  食の安全とリスクからせまる環境教育プログラムの開発
# 14    自立と共生から考える高齢社会～高校生が今できること、将来に向けて身につけること
# 15               幼児期におけるソーシャルスキルを取り入れた養護活動の研究
# 16                  医学と連携した科学教育の礎を築く理科教材開発の研究
# 17   離島の環境特性を利用した呼吸器疾患と生活環境との影響解明及び疾患改善に向けた研究
# 18      高齢女性における加齢に伴う筋委縮への新たな治療法の開発を目指した基礎的研究
# 19               薬科大学女子学生における月経関連症状と生殖的健康について
# 20       子宮頸がん検診低受診率の解明と子宮頸がん予防対策の効果的な実践方法の検討
# 21   下半身陽圧負荷装置を用いた歩行運動が下肢痛を有する高齢者の運動機能に及びぼす影響
# 22                スポーツ競技向上のための特定部分追従動作撮影機構の開発
# 23              「森の幼稚園」における幼児の体力・運動能力を向上させる要因
# 24               足部内の力学作用が立位姿勢・バランス保持能力に及ぼす影響
# 25      体育授業における思考・判断を促すＩＣＴを利用した指導方法に関する実践的研究
# 26                        生徒が主体的に取り組む持久走の授業研究
# 27     課題を正確にとらえ，「わかる」と「できる」を結びつける，体育学習の実践的研究
# 28             小学校体育におけるゲームを楽しむ子どもを育てるための授業開発
# 29         屋外の運動が制限される地域での体力向上を目指した体育授業モデルの開発
# ..                                        ...
# 470       QFT-Plusによる結核診断能評価および新規結核バイオマーカーの探索
# 471         HBV感染に伴う細胞老化の評価と抗HBV核酸アナログがもたらす効果
# 472         ヘルペスウィルス再活性化による抗腫瘍効果の機序とその最適化点の解明
# 473     HIV感染経過におけるADCC作用に関する包括的症例検証およびその発展研究
# 474         迅速な組換え生ワクチン作製を可能とするプラットフォームの開発と検証
# 475            効率的な抗インフルエンザメモリーCD8 T細胞の誘導法の開発
# 476             薬剤耐性プラスミドの接合伝達系を標的とした新規抗菌法の開発
# 477                 粘膜免疫誘導型新規感染性ウイルス腸炎ワクチンの開発
# 478   宿主酵素を標的分子とした新規治療薬の開発：高病原性ウイルス感染症の新たな制御法
# 479            抗菌薬の臨床的ブレイクポイント設定及び検証のためのモデル構築
# 480  感染症診断の新しいアプローチ‐B型肝炎ウイルス感染における爪と毛髪の有用性の検討
# 481  赤血球ATP受容体シグナリングを標的にマラリア感染を防ぐ：耐性のない治療法の確立
# 482             劇症型感染における起因菌および外毒素の新規迅速分析法の確立
# 483         難治性感染症の再燃と蔓延を阻止する治療戦略の開発とビッグデータ解析
# 484      人獣共通病原菌・犬レンサ球菌が保有する定着性・病原性・薬剤耐性機構の解明
# 485    PNAを用いたLAMP法によるマクロライド耐性梅毒トレポネーマの検出系の開発
# 486    サフラン色素クロシンを粘膜アジュバントとした経鼻インフルエンザワクチンの開発
# 487   新規抗ウイルス自然免疫機構を標的にした抗ウイルス薬スクリーニングシステムの開発
# 488        A群連鎖球菌spy1588遺伝子の酸感受性機構と病原性発症機構の解明
# 489    原発避難区域を含む福島県内全域のダニ媒介性感染症の調査と新たな診断手法の開発
# 490   サイトメガロウイルスの感染細胞指向性をエピジェネティックに型判別する方法の開発
# 491   プロバイオティクスを用いた放射線性腸管粘膜障害の改善と敗血症発症抑制効果の検討
# 492                   RNAiを用いた真菌血症に対する新たな治療戦略
# 493           アポリポタンパク質Eの抗ウイルスメカニズムと感染病態機構の解明
# 494  次世代シークエンスを活用した高精細ヒトT細胞白血病ウイルス遺伝子発現制御機序解明
# 495   ケモカイン受容体多量体形成阻害機構解明によるHIV感染の病態解明と治療への応用
# 496            HIV-1キャプシド構造タンパク質自壊と脱殻の新たな機構解明
# 497                        各種アルボウイルスの鑑別診断法の開発
# 498         高齢者C型慢性肝炎における抗ウイルス療法完治後の肝癌発症機序の解明
# 499              マクロファージのPerforin-2による殺菌機構の解明
#
#                                               title_en
# 0    Understanding brain plasticity on body represe...
# 1    Novel measurement techniques for visualizing '...
# 2    Cognitive Interaction Design: A Model-Based Un...
# 3       Prevention of brain protein aging and dementia
# 4                                Nascent-chain Biology
# 5    Establishing a new paradigm of the pathogenesi...
# 6    Cell competition: a mechanism for survival of ...
# 7                       Neo-taxonomy of noncoding RNAs
# 8    Mechanisms underlying the functional shift of ...
# 9    Oxygen biology: a new criterion for integrated...
# 10   Homeostatic Regulation by Various Types of Cel...
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 470                                                NaN
# 471                                                NaN
# 472                                                NaN
# 473                                                NaN
# 474                                                NaN
# 475                                                NaN
# 476                                                NaN
# 477                                                NaN
# 478                                                NaN
# 479                                                NaN
# 480                                                NaN
# 481                                                NaN
# 482                                                NaN
# 483                                                NaN
# 484                                                NaN
# 485                                                NaN
# 486                                                NaN
# 487                                                NaN
# 488                                                NaN
# 489                                                NaN
# 490                                                NaN
# 491                                                NaN
# 492                                                NaN
# 493                                                NaN
# 494                                                NaN
# 495                                                NaN
# 496                                                NaN
# 497                                                NaN
# 498                                                NaN
# 499                                                NaN
#
# [146127 rows x 11 columns]

# %%
df.duplicated().any()
# Out:
# False

# %%
df['awardnumber'].nunique(dropna=False)
# Out:
# 146127

# %%
df = df.set_index('awardnumber')
df
# Out:
#             projecttype          category category_niicode section  \
# awardnumber
# 4603               area  新学術領域研究(研究領域提案型)               73     NaN
# 4602               area  新学術領域研究(研究領域提案型)               73     NaN
# 4601               area  新学術領域研究(研究領域提案型)               73     NaN
# 3608               area  新学術領域研究(研究領域提案型)               73     NaN
# 3607               area  新学術領域研究(研究領域提案型)               73     NaN
# 3606               area  新学術領域研究(研究領域提案型)               73     NaN
# 3605               area  新学術領域研究(研究領域提案型)               73     NaN
# 3604               area  新学術領域研究(研究領域提案型)               73     NaN
# 3603               area  新学術領域研究(研究領域提案型)               73     NaN
# 3602               area  新学術領域研究(研究領域提案型)               73     NaN
# 3601               area  新学術領域研究(研究領域提案型)               73     NaN
# 26935006        project              奨励研究               63     NaN
# 26935005        project              奨励研究               63     NaN
# 26935004        project              奨励研究               63     NaN
# 26935003        project              奨励研究               63     NaN
# 26935002        project              奨励研究               63     NaN
# 26935001        project              奨励研究               63     NaN
# 26934018        project              奨励研究               63     NaN
# 26934017        project              奨励研究               63     NaN
# 26934016        project              奨励研究               63     NaN
# 26934015        project              奨励研究               63     NaN
# 26934014        project              奨励研究               63     NaN
# 26934013        project              奨励研究               63     NaN
# 26934012        project              奨励研究               63     NaN
# 26934011        project              奨励研究               63     NaN
# 26934010        project              奨励研究               63     NaN
# 26934009        project              奨励研究               63     NaN
# 26934008        project              奨励研究               63     NaN
# 26934007        project              奨励研究               63     NaN
# 26934006        project              奨励研究               63     NaN
# ...                 ...               ...              ...     ...
# 18K08461        project           基盤研究(C)               72      一般
# 18K08460        project           基盤研究(C)               72      一般
# 18K08459        project           基盤研究(C)               72      一般
# 18K08458        project           基盤研究(C)               72      一般
# 18K08457        project           基盤研究(C)               72      一般
# 18K08456        project           基盤研究(C)               72      一般
# 18K08455        project           基盤研究(C)               72      一般
# 18K08454        project           基盤研究(C)               72      一般
# 18K08453        project           基盤研究(C)               72      一般
# 18K08452        project           基盤研究(C)               72      一般
# 18K08451        project           基盤研究(C)               72      一般
# 18K08450        project           基盤研究(C)               72      一般
# 18K08449        project           基盤研究(C)               72      一般
# 18K08448        project           基盤研究(C)               72      一般
# 18K08447        project           基盤研究(C)               72      一般
# 18K08446        project           基盤研究(C)               72      一般
# 18K08445        project           基盤研究(C)               72      一般
# 18K08444        project           基盤研究(C)               72      一般
# 18K08443        project           基盤研究(C)               72      一般
# 18K08442        project           基盤研究(C)               72      一般
# 18K08441        project           基盤研究(C)               72      一般
# 18K08440        project           基盤研究(C)               72      一般
# 18K08439        project           基盤研究(C)               72      一般
# 18K08438        project           基盤研究(C)               72      一般
# 18K08437        project           基盤研究(C)               72      一般
# 18K08436        project           基盤研究(C)               72      一般
# 18K08435        project           基盤研究(C)               72      一般
# 18K08434        project           基盤研究(C)               72      一般
# 18K08433        project           基盤研究(C)               72      一般
# 18K08432        project           基盤研究(C)               72      一般
#
#             section_niicode startfiscalyear endfiscalyear directcost  \
# awardnumber
# 4603                    NaN            2014          2018        NaN
# 4602                    NaN            2014          2018        NaN
# 4601                    NaN            2014          2018        NaN
# 3608                    NaN            2014          2018        NaN
# 3607                    NaN            2014          2018        NaN
# 3606                    NaN            2014          2018        NaN
# 3605                    NaN            2014          2018        NaN
# 3604                    NaN            2014          2018        NaN
# 3603                    NaN            2014          2018        NaN
# 3602                    NaN            2014          2018        NaN
# 3601                    NaN            2014          2018        NaN
# 26935006                NaN            2014          2014     600000
# 26935005                NaN            2014          2014     400000
# 26935004                NaN            2014          2014     400000
# 26935003                NaN            2014          2014     600000
# 26935002                NaN            2014          2014     400000
# 26935001                NaN            2014          2014     600000
# 26934018                NaN            2014          2014     600000
# 26934017                NaN            2014          2014     600000
# 26934016                NaN            2014          2014     400000
# 26934015                NaN            2014          2014     300000
# 26934014                NaN            2014          2015     600000
# 26934013                NaN            2014          2014     500000
# 26934012                NaN            2014          2014     600000
# 26934011                NaN            2014          2014     400000
# 26934010                NaN            2014          2014     500000
# 26934009                NaN            2014          2014     500000
# 26934008                NaN            2014          2014     300000
# 26934007                NaN            2014          2014     400000
# 26934006                NaN            2014          2014     300000
# ...                     ...             ...           ...        ...
# 18K08461                 17            2018          2020    3400000
# 18K08460                 17            2018          2020    3400000
# 18K08459                 17            2018          2020    3300000
# 18K08458                 17            2018          2020    3500000
# 18K08457                 17            2018          2020    3400000
# 18K08456                 17            2018          2020    3400000
# 18K08455                 17            2018          2020    3400000
# 18K08454                 17            2018          2020    3400000
# 18K08453                 17            2018          2020    3400000
# 18K08452                 17            2018          2020    3400000
# 18K08451                 17            2018          2020    3500000
# 18K08450                 17            2018          2020    3300000
# 18K08449                 17            2018          2020    3400000
# 18K08448                 17            2018          2020    3400000
# 18K08447                 17            2018          2020    3400000
# 18K08446                 17            2018          2020    3400000
# 18K08445                 17            2018          2020    3200000
# 18K08444                 17            2018          2020    3400000
# 18K08443                 17            2018          2021    3400000
# 18K08442                 17            2018          2022    3300000
# 18K08441                 17            2018          2020    3200000
# 18K08440                 17            2018          2020    1500000
# 18K08439                 17            2018          2020    3200000
# 18K08438                 17            2018          2020    3400000
# 18K08437                 17            2018          2020    3400000
# 18K08436                 17            2018          2020    3300000
# 18K08435                 17            2018          2020    3400000
# 18K08434                 17            2018          2020    3500000
# 18K08433                 17            2018          2020    3400000
# 18K08432                 17            2018          2020    3400000
#
#                                              title_ja  \
# awardnumber
# 4603                                脳内身体表現の変容機構の理解と制御
# 4602             動的構造生命科学を拓く新発想測定技術－タンパク質が動作する姿を活写する－
# 4601          認知的インタラクションデザイン学：意思疎通のモデル論的理解と人工物設計への応用
# 3608                                   脳タンパク質老化と認知症制御
# 3607                                          新生鎖の生物学
# 3606                             ステムセルエイジングから解明する疾患原理
# 3605                            細胞競合：細胞社会を支える適者生存システム
# 3604                               ノンコーディングＲＮＡネオタクソノミ
# 3603                             行動適応を担う脳神経回路の機能シフト機構
# 3602                              酸素を基軸とする生命の新たな統合的理解
# 3601                           細胞死を起点とする生体制御ネットワークの解明
# 26935006       超高精細４Ｋ映像による可視化金型粉砕機を用いたアルファ穀物粉の粉砕挙動の解明
# 26935005           小学校における持続可能な社会をめざすための消費者教育の実践事例集作成
# 26935004                    食の安全とリスクからせまる環境教育プログラムの開発
# 26935003      自立と共生から考える高齢社会～高校生が今できること、将来に向けて身につけること
# 26935002                 幼児期におけるソーシャルスキルを取り入れた養護活動の研究
# 26935001                    医学と連携した科学教育の礎を築く理科教材開発の研究
# 26934018     離島の環境特性を利用した呼吸器疾患と生活環境との影響解明及び疾患改善に向けた研究
# 26934017        高齢女性における加齢に伴う筋委縮への新たな治療法の開発を目指した基礎的研究
# 26934016                 薬科大学女子学生における月経関連症状と生殖的健康について
# 26934015         子宮頸がん検診低受診率の解明と子宮頸がん予防対策の効果的な実践方法の検討
# 26934014     下半身陽圧負荷装置を用いた歩行運動が下肢痛を有する高齢者の運動機能に及びぼす影響
# 26934013                  スポーツ競技向上のための特定部分追従動作撮影機構の開発
# 26934012                「森の幼稚園」における幼児の体力・運動能力を向上させる要因
# 26934011                 足部内の力学作用が立位姿勢・バランス保持能力に及ぼす影響
# 26934010        体育授業における思考・判断を促すＩＣＴを利用した指導方法に関する実践的研究
# 26934009                          生徒が主体的に取り組む持久走の授業研究
# 26934008       課題を正確にとらえ，「わかる」と「できる」を結びつける，体育学習の実践的研究
# 26934007               小学校体育におけるゲームを楽しむ子どもを育てるための授業開発
# 26934006           屋外の運動が制限される地域での体力向上を目指した体育授業モデルの開発
# ...                                               ...
# 18K08461          QFT-Plusによる結核診断能評価および新規結核バイオマーカーの探索
# 18K08460            HBV感染に伴う細胞老化の評価と抗HBV核酸アナログがもたらす効果
# 18K08459            ヘルペスウィルス再活性化による抗腫瘍効果の機序とその最適化点の解明
# 18K08458        HIV感染経過におけるADCC作用に関する包括的症例検証およびその発展研究
# 18K08457            迅速な組換え生ワクチン作製を可能とするプラットフォームの開発と検証
# 18K08456               効率的な抗インフルエンザメモリーCD8 T細胞の誘導法の開発
# 18K08455                薬剤耐性プラスミドの接合伝達系を標的とした新規抗菌法の開発
# 18K08454                    粘膜免疫誘導型新規感染性ウイルス腸炎ワクチンの開発
# 18K08453      宿主酵素を標的分子とした新規治療薬の開発：高病原性ウイルス感染症の新たな制御法
# 18K08452               抗菌薬の臨床的ブレイクポイント設定及び検証のためのモデル構築
# 18K08451     感染症診断の新しいアプローチ‐B型肝炎ウイルス感染における爪と毛髪の有用性の検討
# 18K08450     赤血球ATP受容体シグナリングを標的にマラリア感染を防ぐ：耐性のない治療法の確立
# 18K08449                劇症型感染における起因菌および外毒素の新規迅速分析法の確立
# 18K08448            難治性感染症の再燃と蔓延を阻止する治療戦略の開発とビッグデータ解析
# 18K08447         人獣共通病原菌・犬レンサ球菌が保有する定着性・病原性・薬剤耐性機構の解明
# 18K08446       PNAを用いたLAMP法によるマクロライド耐性梅毒トレポネーマの検出系の開発
# 18K08445       サフラン色素クロシンを粘膜アジュバントとした経鼻インフルエンザワクチンの開発
# 18K08444      新規抗ウイルス自然免疫機構を標的にした抗ウイルス薬スクリーニングシステムの開発
# 18K08443           A群連鎖球菌spy1588遺伝子の酸感受性機構と病原性発症機構の解明
# 18K08442       原発避難区域を含む福島県内全域のダニ媒介性感染症の調査と新たな診断手法の開発
# 18K08441      サイトメガロウイルスの感染細胞指向性をエピジェネティックに型判別する方法の開発
# 18K08440      プロバイオティクスを用いた放射線性腸管粘膜障害の改善と敗血症発症抑制効果の検討
# 18K08439                      RNAiを用いた真菌血症に対する新たな治療戦略
# 18K08438              アポリポタンパク質Eの抗ウイルスメカニズムと感染病態機構の解明
# 18K08437     次世代シークエンスを活用した高精細ヒトT細胞白血病ウイルス遺伝子発現制御機序解明
# 18K08436      ケモカイン受容体多量体形成阻害機構解明によるHIV感染の病態解明と治療への応用
# 18K08435               HIV-1キャプシド構造タンパク質自壊と脱殻の新たな機構解明
# 18K08434                           各種アルボウイルスの鑑別診断法の開発
# 18K08433            高齢者C型慢性肝炎における抗ウイルス療法完治後の肝癌発症機序の解明
# 18K08432                 マクロファージのPerforin-2による殺菌機構の解明
#
#                                                       title_en
# awardnumber
# 4603         Understanding brain plasticity on body represe...
# 4602         Novel measurement techniques for visualizing '...
# 4601         Cognitive Interaction Design: A Model-Based Un...
# 3608            Prevention of brain protein aging and dementia
# 3607                                     Nascent-chain Biology
# 3606         Establishing a new paradigm of the pathogenesi...
# 3605         Cell competition: a mechanism for survival of ...
# 3604                            Neo-taxonomy of noncoding RNAs
# 3603         Mechanisms underlying the functional shift of ...
# 3602         Oxygen biology: a new criterion for integrated...
# 3601         Homeostatic Regulation by Various Types of Cel...
# 26935006                                                   NaN
# 26935005                                                   NaN
# 26935004                                                   NaN
# 26935003                                                   NaN
# 26935002                                                   NaN
# 26935001                                                   NaN
# 26934018                                                   NaN
# 26934017                                                   NaN
# 26934016                                                   NaN
# 26934015                                                   NaN
# 26934014                                                   NaN
# 26934013                                                   NaN
# 26934012                                                   NaN
# 26934011                                                   NaN
# 26934010                                                   NaN
# 26934009                                                   NaN
# 26934008                                                   NaN
# 26934007                                                   NaN
# 26934006                                                   NaN
# ...                                                        ...
# 18K08461                                                   NaN
# 18K08460                                                   NaN
# 18K08459                                                   NaN
# 18K08458                                                   NaN
# 18K08457                                                   NaN
# 18K08456                                                   NaN
# 18K08455                                                   NaN
# 18K08454                                                   NaN
# 18K08453                                                   NaN
# 18K08452                                                   NaN
# 18K08451                                                   NaN
# 18K08450                                                   NaN
# 18K08449                                                   NaN
# 18K08448                                                   NaN
# 18K08447                                                   NaN
# 18K08446                                                   NaN
# 18K08445                                                   NaN
# 18K08444                                                   NaN
# 18K08443                                                   NaN
# 18K08442                                                   NaN
# 18K08441                                                   NaN
# 18K08440                                                   NaN
# 18K08439                                                   NaN
# 18K08438                                                   NaN
# 18K08437                                                   NaN
# 18K08436                                                   NaN
# 18K08435                                                   NaN
# 18K08434                                                   NaN
# 18K08433                                                   NaN
# 18K08432                                                   NaN
#
# [146127 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 146127 entries, 4603 to 18K08432
# Data columns (total 10 columns):
# projecttype         146127 non-null object
# category            146127 non-null object
# category_niicode    146127 non-null object
# section             88229 non-null object
# section_niicode     88229 non-null object
# startfiscalyear     146127 non-null object
# endfiscalyear       146127 non-null object
# directcost          146037 non-null object
# title_ja            145982 non-null object
# title_en            33396 non-null object
# dtypes: object(10)
# memory usage: 12.3+ MB

# %%
df = df.fillna(0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 146127 entries, 4603 to 18K08432
# Data columns (total 10 columns):
# projecttype         146127 non-null object
# category            146127 non-null object
# category_niicode    146127 non-null object
# section             146127 non-null object
# section_niicode     146127 non-null object
# startfiscalyear     146127 non-null object
# endfiscalyear       146127 non-null object
# directcost          146127 non-null object
# title_ja            146127 non-null object
# title_en            146127 non-null object
# dtypes: object(10)
# memory usage: 12.3+ MB

# %%
df = df.astype({
    'category_niicode': np.int64,
    'section_niicode': np.int64,
    'startfiscalyear': np.int64,
    'endfiscalyear': np.int64,
    'directcost': np.int64,
})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 146127 entries, 4603 to 18K08432
# Data columns (total 10 columns):
# projecttype         146127 non-null object
# category            146127 non-null object
# category_niicode    146127 non-null int64
# section             146127 non-null object
# section_niicode     146127 non-null int64
# startfiscalyear     146127 non-null int64
# endfiscalyear       146127 non-null int64
# directcost          146127 non-null int64
# title_ja            146127 non-null object
# title_en            146127 non-null object
# dtypes: int64(5), object(5)
# memory usage: 12.3+ MB

# %%
df['directcost'] = df['directcost'].map(lambda x: x // 1000)

# %%
pd.crosstab(df['category_niicode'], df['startfiscalyear'], margins=True)
# Out:
# startfiscalyear    2014   2015   2016   2017   2018     All
# category_niicode
# 28                   14     14     14     13     12      67
# 42                 2819   2691   2694   2543   2308   13055
# 55                    4      3      3      4      0      14
# 60                   87     87     95     82     80     431
# 63                  708    708    736    725    557    3434
# 64                  408    390    423    433      0    1654
# 65                 5886   5745   5735   5817      0   23183
# 68                  632    597    634    636    605    3104
# 69                 2623   2725   2929   2816   2965   14058
# 72                10580  11389  11814  12054  12175   58012
# 73                 1052   1073   1091   1028    875    5119
# 75                 3950   3952   3613      0      0   11515
# 76                  919    939    929    946      0    3733
# 77                    0     42    429    300      0     771
# 79                    0      7     19      8      0      34
# 247                   0      0      7      0      0       7
# 249                   0      0      0     94      0      94
# 250                   0      0      0   1586      0    1586
# 252                   0      0      0      0   6256    6256
# All               29682  30362  31165  29085  25833  146127

# %%
df[df['category_niicode'] == 0]
# Out:
# Empty DataFrame
# Columns: [projecttype, category, category_niicode, section, section_niicode, startfiscalyear, endfiscalyear, directcost, title_ja, title_en]
# Index: []

# %%
df.loc['22128009', 'category_niicode'] = 73 #  新学術領域研究(研究領域提案型)
df.loc['22900002', 'category_niicode'] = 55 #  特別研究推進費
df.loc['22900001', 'category_niicode'] = 55 #  特別研究推進費
df.loc['11F01767', 'category_niicode'] = 42 #  特別研究員奨励費
df.loc['11F01514', 'category_niicode'] = 42 #  特別研究員奨励費
df.loc['11F01303', 'category_niicode'] = 42 #  特別研究員奨励費
df.loc['23900002', 'category_niicode'] = 55 #  特別研究推進費
df.loc['23900001', 'category_niicode'] = 55 #  特別研究推進費
df.loc['24900001', 'category_niicode'] = 55 #  特別研究推進費

# %%
pd.crosstab(df['category_niicode'], df['startfiscalyear'], margins=True)
# Out:
# startfiscalyear   2014.0  2015.0  2016.0  2017.0  2018.0     All
# category_niicode
# 28.0                  14      14      14      13      12      67
# 42.0                2819    2691    2694    2543    2308   13055
# 55.0                   4       3       3       4       0      14
# 60.0                  87      87      95      82      80     431
# 63.0                 708     708     736     725     557    3434
# 64.0                 408     390     423     433       0    1654
# 65.0                5886    5745    5735    5817       0   23183
# 68.0                 632     597     634     636     605    3104
# 69.0                2623    2725    2929    2816    2965   14058
# 72.0               10580   11389   11814   12054   12175   58012
# 73.0                1052    1073    1091    1028     875    5119
# 75.0                3950    3952    3613       0       0   11515
# 76.0                 919     939     929     946       0    3733
# 77.0                   0      42     429     300       0     771
# 79.0                   0       7      19       8       0      34
# 247.0                  0       0       7       0       0       7
# 249.0                  0       0       0      94       0      94
# 250.0                  0       0       0    1586       0    1586
# 252.0                  0       0       0       0    6256    6256
# All                29682   30362   31165   29085   25833  146127

# %%
df.to_pickle('afterCleaning/parse_kadai.dump')
