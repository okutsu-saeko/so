# %%
#ちゃんと動いた

import requests
import json

url = 'http://api.elsevier.com/content/search/scopus?'
api = 'a9a8aa106b9cfd22b26747e6557a072c'
query = 'query=heart'
header = {'Accept': 'application/json', 'X-ELS-APIKey': api}


req = requests.get(url+query, headers=header)
print(req.url)

page = json.loads(req.content.decode("utf-8"))
print(page)
# Out:
# https://api.elsevier.com/content/search/scopus?query=heart
# ...
